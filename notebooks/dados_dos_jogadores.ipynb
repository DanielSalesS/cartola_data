# %% [markdown]
# ## Obter, filtrar e salvar os dados dos jogadores.

# %%
import json
import path_config
from cartola.api import ApiClient
from cartola.cartola_settings import scout_keys, clubs, club_ids, dynamic_api
from cartola.processdata import Players

# %% [markdown]
# ## Selecionando uma rodada antiga

# %%
status = ApiClient(url=dynamic_api['status'])
rodada_atual = status.get_data_by_key(key='rodada_atual')
# Out:
# 1

# %%
target_data = [
    'clube_id',
    'nome',
    'slug',
    'apelido',
    'atleta_id',
    'rodada_id',
    'posicao_id',
    'status_id',
    'pontos_num',
    'preco_num',
    'variacao_num',
    'media_num',
    'jogos_num',
    'scout',
]

dados_rodada = ApiClient(url="https://api.cartolafc.globo.com/atletas/mercado")
json_data = dados_rodada.get_json()
atletas = json_data['atletas']
players = Players(json_data=atletas)
players.pre_processing(target_data=target_data, scout_keys=scout_keys)

# Agrupa jogadores pelas keys associadas aos id's.
group_by_key = {k: value for k, value in zip(club_ids, clubs)}
players.group_data(group_by_key=group_by_key)
dir_path = fr'csv_files/rodada{rodada_atual}'
# Separa as informações por key e salva separadamente os arquivos.
players.save_individual_csv(save_by_key=clubs, dir_path=dir_path)
# Salva todos os dados em um único arquivo.
players.save_csv(path=dir_path + r'/all_players.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-d064e45f98b4> in <module>
#      24 # Agrupa jogadores pelas keys associadas aos id's.
#      25 group_by_key = {k: value for k, value in zip(club_ids, clubs)}
# ---> 26 players.group_data(group_by_key=group_by_key)
#      27 dir_path = fr'csv_files/rodada{rodada_atual}'
#      28 # Separa as informações por key e salva separadamente os arquivos.
#
# ~/estudos/python/cartola_data/cartola/processdata.py in group_data(self, group_by_key)
#     122         for player in self.processed_data:
#     123             clube_id = player['clube_id']
# --> 124             key = group_by_key[str(clube_id)]
#     125             self.grouped_data[key].append(player)
#     126
#
# KeyError: '1371'

# %%
json_data
# Out:
# {'atletas': [{'nome': 'Weverton Pereira da Silva',
#    'slug': 'weverton',
#    'apelido': 'Weverton',
#    'apelido_abreviado': 'Weverton',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/30/33d63334ddcba3f0e0150bb2c5aadd75_FORMATO.png',
#    'atleta_id': 71631,
#    'rodada_id': 1,
#    'clube_id': 275,
#    'posicao_id': 1,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 20,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Filipe Luís Kasmirski',
#    'slug': 'filipe-luis',
#    'apelido': 'Filipe Luís',
#    'apelido_abreviado': 'F. Luís',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/05/01/d86e6ac0aeabadf61f4625bb2f705863_FORMATO.png',
#    'atleta_id': 38750,
#    'rodada_id': 1,
#    'clube_id': 262,
#    'posicao_id': 2,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 5,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Douglas Alan Schuck Friedrich',
#    'slug': 'douglas-friedrich',
#    'apelido': 'Douglas Friedrich',
#    'apelido_abreviado': 'D. Friedrich',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/19/9d3826170ce7335b3b294256a794129e_FORMATO.png',
#    'atleta_id': 78584,
#    'rodada_id': 1,
#    'clube_id': 265,
#    'posicao_id': 1,
#    'status_id': 6,
#    'pontos_num': 0,
#    'preco_num': 6,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Luis Eduardo Barros Cavalcanti',
#    'slug': 'dado-cavalcanti',
#    'apelido': 'Dado Cavalcanti',
#    'apelido_abreviado': 'D. Cavalcanti',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/27/d35dc59e19f369d5bebf2ca870749b72_FORMATO.png',
#    'atleta_id': 73975,
#    'rodada_id': 1,
#    'clube_id': 265,
#    'posicao_id': 6,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 4,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Fagner Conserva Lemos',
#    'slug': 'fagner',
#    'apelido': 'Fagner',
#    'apelido_abreviado': 'Fagner',
#    'foto': 'https://s.glbimg.com/es/sde/f/2020/07/21/86994a3b5f98e1f43ef23a09d56aa65c_FORMATO.png',
#    'atleta_id': 42500,
#    'rodada_id': 1,
#    'clube_id': 264,
#    'posicao_id': 2,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 14,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Vagner Carmo Mancini',
#    'slug': 'vagner-mancini',
#    'apelido': 'Vagner Mancini',
#    'apelido_abreviado': 'V. Mancini',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/28/5745220dd2c869e1f9de357e41902989_FORMATO.png',
#    'atleta_id': 39850,
#    'rodada_id': 1,
#    'clube_id': 264,
#    'posicao_id': 6,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 6,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Alberto Valentim do Carmo Neto',
#    'slug': 'alberto-valentim',
#    'apelido': 'Alberto Valentim',
#    'apelido_abreviado': 'A. Valentim',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/27/330fee85f00a26093f7e85cf80e57bbc_FORMATO.png',
#    'atleta_id': 84863,
#    'rodada_id': 1,
#    'clube_id': 1371,
#    'posicao_id': 6,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 2,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Anderson Luiz de Carvalho',
#    'slug': 'nene',
#    'apelido': 'Nenê',
#    'apelido_abreviado': 'Nenê',
#    'foto': 'https://s.glbimg.com/es/sde/f/2020/08/11/f3df6bdc76524f571ea66cc968ab62af_FORMATO.png',
#    'atleta_id': 38913,
#    'rodada_id': 1,
#    'clube_id': 266,
#    'posicao_id': 4,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 12,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Gabriel Barbosa Almeida',
#    'slug': 'gabriel',
#    'apelido': 'Gabriel',
#    'apelido_abreviado': 'Gabriel',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/05/01/a1cd90e3261b3c17b68fe4bc2fa82ef0_FORMATO.png',
#    'atleta_id': 83257,
#    'rodada_id': 1,
#    'clube_id': 262,
#    'posicao_id': 5,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 22,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Pedro Tonon Geromel',
#    'slug': 'pedro-geromel',
#    'apelido': 'Pedro Geromel',
#    'apelido_abreviado': 'P. Geromel',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/29/2911dfa228866bcf4526969aee375081_FORMATO.png',
#    'atleta_id': 80853,
#    'rodada_id': 1,
#    'clube_id': 284,
#    'posicao_id': 3,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 15,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Mateus da Silva Vital Assumpção',
#    'slug': 'mateus-vital',
#    'apelido': 'Mateus Vital',
#    'apelido_abreviado': 'M. Vital',
#    'foto': 'https://s.glbimg.com/es/sde/f/2020/07/21/5dcf880865714624f3dd33ea666f3d81_FORMATO.png',
#    'atleta_id': 93108,
#    'rodada_id': 1,
#    'clube_id': 264,
#    'posicao_id': 4,
#    'status_id': 6,
#    'pontos_num': 0,
#    'preco_num': 8,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Rosicley Pereira da Silva',
#    'slug': 'rossi',
#    'apelido': 'Rossi',
#    'apelido_abreviado': 'Rossi',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/19/7d895a5c5d4a6d56fb3ce7566c6b0fd6_FORMATO.png',
#    'atleta_id': 81798,
#    'rodada_id': 1,
#    'clube_id': 265,
#    'posicao_id': 5,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 8,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Clayson Henrique da Silva Vieira',
#    'slug': 'clayson',
#    'apelido': 'Clayson',
#    'apelido_abreviado': 'Clayson',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/03/30/7ecb7515114debd6f7c6e1a32ea6411d_FORMATO.png',
#    'atleta_id': 83817,
#    'rodada_id': 1,
#    'clube_id': 1371,
#    'posicao_id': 5,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 5,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Mauricio Aníbal Isla Isla',
#    'slug': 'isla',
#    'apelido': 'Isla',
#    'apelido_abreviado': 'Isla',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/05/01/0f714292e3b8da4992a408c35794cb18_FORMATO.png',
#    'atleta_id': 69345,
#    'rodada_id': 1,
#    'clube_id': 262,
#    'posicao_id': 2,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 10,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Rogério Ceni',
#    'slug': 'rogerio-ceni',
#    'apelido': 'Rogério Ceni',
#    'apelido_abreviado': 'R. Ceni',
#    'foto': 'https://s.glbimg.com/es/sde/f/2020/11/09/8879b35c72aef797d229636dbdf3dd4f_FORMATO.png',
#    'atleta_id': 97341,
#    'rodada_id': 1,
#    'clube_id': 262,
#    'posicao_id': 6,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 12,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Gilberto Oliveira Souza Júnior',
#    'slug': 'gilberto',
#    'apelido': 'Gilberto',
#    'apelido_abreviado': 'Gilberto',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/19/084597dfc92b63b3485d5ed7b75cdfa6_FORMATO.png',
#    'atleta_id': 61188,
#    'rodada_id': 1,
#    'clube_id': 265,
#    'posicao_id': 5,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 5,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Everton Augusto de Barros Ribeiro',
#    'slug': 'everton-ribeiro',
#    'apelido': 'Everton Ribeiro',
#    'apelido_abreviado': 'E. Ribeiro',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/05/01/0b74b3625a59431fcb48ceb25a5c520a_FORMATO.png',
#    'atleta_id': 51772,
#    'rodada_id': 1,
#    'clube_id': 262,
#    'posicao_id': 4,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 12,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Diego Ribas da Cunha',
#    'slug': 'diego',
#    'apelido': 'Diego',
#    'apelido_abreviado': 'Diego',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/05/01/6584e15d2928d6fbac297573a2a35b98_FORMATO.png',
#    'atleta_id': 38909,
#    'rodada_id': 1,
#    'clube_id': 262,
#    'posicao_id': 4,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 8,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Renê Rodrigues Martins',
#    'slug': 'rene',
#    'apelido': 'Renê',
#    'apelido_abreviado': 'Renê',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/05/01/f236bdf56a7ece63fc2911d8635bed6b_FORMATO.png',
#    'atleta_id': 78445,
#    'rodada_id': 1,
#    'clube_id': 262,
#    'posicao_id': 2,
#    'status_id': 5,
#    'pontos_num': 0,
#    'preco_num': 6,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Renato Kayzer de Souza',
#    'slug': 'renato-kayzer',
#    'apelido': 'Renato Kayzer',
#    'apelido_abreviado': 'R. Kayzer',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/05/02/6f855c82dac6b57f92d9201fff45aef8_FORMATO.png',
#    'atleta_id': 92696,
#    'rodada_id': 1,
#    'clube_id': 293,
#    'posicao_id': 5,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 11,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Gerson Santos da Silva',
#    'slug': 'gerson',
#    'apelido': 'Gerson',
#    'apelido_abreviado': 'Gerson',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/05/01/e00ea87215ca1551dfa01d43e6a76168_FORMATO.png',
#    'atleta_id': 89256,
#    'rodada_id': 1,
#    'clube_id': 262,
#    'posicao_id': 4,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 12,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Rodrigo Caio Coquette Russo',
#    'slug': 'rodrigo-caio',
#    'apelido': 'Rodrigo Caio',
#    'apelido_abreviado': 'R. Caio',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/05/01/361e833ec8151b521da956148bee92e5_FORMATO.png',
#    'atleta_id': 73800,
#    'rodada_id': 1,
#    'clube_id': 262,
#    'posicao_id': 3,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 11,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Natanael Batista Pimenta',
#    'slug': 'natanael',
#    'apelido': 'Natanael',
#    'apelido_abreviado': 'Natanael',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/05/01/8d7a42fcd53a8f290188c60783071a94_FORMATO.png',
#    'atleta_id': 86264,
#    'rodada_id': 1,
#    'clube_id': 373,
#    'posicao_id': 2,
#    'status_id': 5,
#    'pontos_num': 0,
#    'preco_num': 4,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Augusto Sérgio Ferreira',
#    'slug': 'guto-ferreira',
#    'apelido': 'Guto Ferreira',
#    'apelido_abreviado': 'G. Ferreira',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/27/7b5d614f3eafc2e2e12922930cd3590e_FORMATO.png',
#    'atleta_id': 37245,
#    'rodada_id': 1,
#    'clube_id': 354,
#    'posicao_id': 6,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 8,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Victor Vinícius Coelho dos Santos',
#    'slug': 'vitinho',
#    'apelido': 'Vitinho',
#    'apelido_abreviado': 'Vitinho',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/05/01/4fafe8587e4964a63ebac8db0a7335c5_FORMATO.png',
#    'atleta_id': 78435,
#    'rodada_id': 1,
#    'clube_id': 262,
#    'posicao_id': 5,
#    'status_id': 6,
#    'pontos_num': 0,
#    'preco_num': 7,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'João Paulo Gomes da Costa',
#    'slug': 'joao-paulo',
#    'apelido': 'João Paulo',
#    'apelido_abreviado': 'J. Paulo',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/03/29/d54f6d5549db0da52f3302ab4e4121b7_FORMATO.png',
#    'atleta_id': 71602,
#    'rodada_id': 1,
#    'clube_id': 327,
#    'posicao_id': 2,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 6,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Luiz Carlos Cirne Lima de Lorenzi',
#    'slug': 'lisca',
#    'apelido': 'Lisca',
#    'apelido_abreviado': 'Lisca',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/28/035bd47807f8e7c0a6cc5dd78a718cf0_FORMATO.png',
#    'atleta_id': 72588,
#    'rodada_id': 1,
#    'clube_id': 327,
#    'posicao_id': 6,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 4,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Marlon Rodrigues Freitas',
#    'slug': 'marlon-freitas',
#    'apelido': 'Marlon Freitas',
#    'apelido_abreviado': 'M. Freitas',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/05/01/441dbd3fa5dc62d8f397990770aa1344_FORMATO.png',
#    'atleta_id': 93790,
#    'rodada_id': 1,
#    'clube_id': 373,
#    'posicao_id': 4,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 6,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Roger Machado Marques',
#    'slug': 'roger-machado',
#    'apelido': 'Roger Machado ',
#    'apelido_abreviado': 'R. Machado',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/27/ec1e7e490c3a05088fd967b9e2468216_FORMATO.png',
#    'atleta_id': 79437,
#    'rodada_id': 1,
#    'clube_id': 266,
#    'posicao_id': 6,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 6,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Fernando Miguel Kaufmann',
#    'slug': 'fernando-miguel',
#    'apelido': 'Fernando Miguel',
#    'apelido_abreviado': 'F. Miguel',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/20/88ab80496dcd025f8e23875c60ede171_FORMATO.png',
#    'atleta_id': 71571,
#    'rodada_id': 1,
#    'clube_id': 373,
#    'posicao_id': 1,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 7,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Bruno Henrique Pinto',
#    'slug': 'bruno-henrique',
#    'apelido': 'Bruno Henrique',
#    'apelido_abreviado': 'B. Henrique',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/05/01/98039adcc6dd9b053c4057c1655e7aeb_FORMATO.png',
#    'atleta_id': 90285,
#    'rodada_id': 1,
#    'clube_id': 262,
#    'posicao_id': 5,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 16,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'José Roberto Assunção de Araújo Filho',
#    'slug': 'ze-roberto',
#    'apelido': 'Zé Roberto',
#    'apelido_abreviado': 'Z. Roberto',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/20/c2fbbd910eaadd1b3c8bebd0f5fc57bb_FORMATO.png',
#    'atleta_id': 80076,
#    'rodada_id': 1,
#    'clube_id': 373,
#    'posicao_id': 5,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 6,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Diego Alves Carreira',
#    'slug': 'diego-alves',
#    'apelido': 'Diego Alves',
#    'apelido_abreviado': 'D. Alves',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/05/01/f3e9b15ef84f4d038e6cfd79171fab69_FORMATO.png',
#    'atleta_id': 38509,
#    'rodada_id': 1,
#    'clube_id': 262,
#    'posicao_id': 1,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 14,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Jorge Amorim de Oliveira Campos',
#    'slug': 'jorginho',
#    'apelido': 'Jorginho',
#    'apelido_abreviado': 'Jorginho',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/27/ed89bb6662d329721f0b34029b57a978_FORMATO.png',
#    'atleta_id': 70323,
#    'rodada_id': 1,
#    'clube_id': 373,
#    'posicao_id': 6,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 3,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Thiago Heleno Henrique Ferreira',
#    'slug': 'thiago-heleno',
#    'apelido': 'Thiago Heleno',
#    'apelido_abreviado': 'T. Heleno',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/05/02/f69df2ecdf5d2a9d11697c61673c4358_FORMATO.png',
#    'atleta_id': 38394,
#    'rodada_id': 1,
#    'clube_id': 293,
#    'posicao_id': 3,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 9,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Pedro Henrique Ribeiro Gonçalves',
#    'slug': 'pedro-henrique',
#    'apelido': 'Pedro Henrique',
#    'apelido_abreviado': 'P. Henrique',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/05/02/f5dd1bb01acb5eb9e0601cc31c8020f5_FORMATO.png',
#    'atleta_id': 87225,
#    'rodada_id': 1,
#    'clube_id': 293,
#    'posicao_id': 3,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 7,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Leonardo Rech Ortiz',
#    'slug': 'leo-ortiz',
#    'apelido': 'Léo Ortiz',
#    'apelido_abreviado': 'L. Ortiz',
#    'foto': 'https://s.glbimg.com/es/sde/f/2020/07/28/090452058da707cf73facf6249235bfb_FORMATO.png',
#    'atleta_id': 97867,
#    'rodada_id': 1,
#    'clube_id': 280,
#    'posicao_id': 3,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 5,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Everson Felipe Marques Pires',
#    'slug': 'everson',
#    'apelido': 'Everson',
#    'apelido_abreviado': 'Everson',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/05/02/2eff4cdfd58d4f859979ef83bbe1ad06_FORMATO.png',
#    'atleta_id': 72294,
#    'rodada_id': 1,
#    'clube_id': 282,
#    'posicao_id': 1,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 13,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Alexi Stival',
#    'slug': 'cuca',
#    'apelido': 'Cuca',
#    'apelido_abreviado': 'Cuca',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/27/0ea32497ac7f6b6b22649eecca984fec_FORMATO.png',
#    'atleta_id': 42411,
#    'rodada_id': 1,
#    'clube_id': 282,
#    'posicao_id': 6,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 11,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Cássio Roberto Ramos',
#    'slug': 'cassio',
#    'apelido': 'Cássio',
#    'apelido_abreviado': 'Cássio',
#    'foto': 'https://s.glbimg.com/es/sde/f/2020/07/21/d69bc6de4b00dce33cf2a3f7303c2c45_FORMATO.png',
#    'atleta_id': 42234,
#    'rodada_id': 1,
#    'clube_id': 264,
#    'posicao_id': 1,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 15,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Marcelo Lomba do Nascimento',
#    'slug': 'marcelo-lomba',
#    'apelido': 'Marcelo Lomba',
#    'apelido_abreviado': 'M. Lomba',
#    'foto': 'https://s.glbimg.com/es/sde/f/2020/02/27/ff4cfd7c9d5ee3bf7c1f281c6a05c147_FORMATO.png',
#    'atleta_id': 68872,
#    'rodada_id': 1,
#    'clube_id': 285,
#    'posicao_id': 1,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 13,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Givanildo Vieira de Souza',
#    'slug': 'hulk',
#    'apelido': 'Hulk',
#    'apelido_abreviado': 'Hulk',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/23/d9ed7fa34aa12e4ce8768c9c2a2b4560_FORMATO.png',
#    'atleta_id': 39148,
#    'rodada_id': 1,
#    'clube_id': 282,
#    'posicao_id': 5,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 13,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Igor Rabello da Costa',
#    'slug': 'igor-rabello',
#    'apelido': 'Igor Rabello',
#    'apelido_abreviado': 'I. Rabello',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/05/02/a3c5d8522641cc6e0c6c72d9dbcc14fd_FORMATO.png',
#    'atleta_id': 89493,
#    'rodada_id': 1,
#    'clube_id': 282,
#    'posicao_id': 3,
#    'status_id': 2,
#    'pontos_num': 0,
#    'preco_num': 9,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Víctor Leandro Cuesta',
#    'slug': 'victor-cuesta',
#    'apelido': 'Víctor Cuesta',
#    'apelido_abreviado': 'V. Cuesta',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/05/02/3f88f0b75e8991f7808e2e7cc7ed35f8_FORMATO.png',
#    'atleta_id': 79113,
#    'rodada_id': 1,
#    'clube_id': 285,
#    'posicao_id': 3,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 16,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Luccas Claro dos Santos',
#    'slug': 'luccas-claro',
#    'apelido': 'Luccas Claro',
#    'apelido_abreviado': 'L. Claro',
#    'foto': 'https://s.glbimg.com/es/sde/f/2020/08/11/1062c554fc9540ac0e4184be2cd0a557_FORMATO.png',
#    'atleta_id': 73465,
#    'rodada_id': 1,
#    'clube_id': 266,
#    'posicao_id': 3,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 10,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Patrick Bezerra do Nascimento',
#    'slug': 'patrick',
#    'apelido': 'Patrick',
#    'apelido_abreviado': 'Patrick',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/05/02/edb310e9b3a541992505fa9f30654040_FORMATO.png',
#    'atleta_id': 83433,
#    'rodada_id': 1,
#    'clube_id': 285,
#    'posicao_id': 4,
#    'status_id': 5,
#    'pontos_num': 0,
#    'preco_num': 14,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Óscar Ramón Ruiz Roa',
#    'slug': 'oscar-ruiz',
#    'apelido': 'Óscar Ruíz',
#    'apelido_abreviado': 'Ã. Ruíz',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/19/e850cf4d6cfc215e774c04bf144994e4_FORMATO.png',
#    'atleta_id': 71691,
#    'rodada_id': 1,
#    'clube_id': 265,
#    'posicao_id': 4,
#    'status_id': 2,
#    'pontos_num': 0,
#    'preco_num': 7,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Fábio Santos Romeu',
#    'slug': 'fabio-santos',
#    'apelido': 'Fábio Santos',
#    'apelido_abreviado': 'F. Santos',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/20/96a1d9072d2146d25f1741af24739dda_FORMATO.png',
#    'atleta_id': 38229,
#    'rodada_id': 1,
#    'clube_id': 264,
#    'posicao_id': 2,
#    'status_id': 6,
#    'pontos_num': 0,
#    'preco_num': 11,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Miguel Ángel Ramírez',
#    'slug': 'miguel-angel-ramirez',
#    'apelido': 'Miguel Ángel Ramírez',
#    'apelido_abreviado': 'M. Ramírez',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/29/8a1faa86eb25d2d5979d8a8e0135379d_FORMATO.png',
#    'atleta_id': 106305,
#    'rodada_id': 1,
#    'clube_id': 285,
#    'posicao_id': 6,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 8,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Paulo Marcos de Jesus Ribeiro',
#    'slug': 'paulao',
#    'apelido': 'Paulão',
#    'apelido_abreviado': 'Paulão',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/03/23/d2f2561de4e5edc9188859d78dea1ba8_FORMATO.png',
#    'atleta_id': 63172,
#    'rodada_id': 1,
#    'clube_id': 1371,
#    'posicao_id': 3,
#    'status_id': 6,
#    'pontos_num': 0,
#    'preco_num': 7,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Eduardo Colcenti Antunes',
#    'slug': 'eduardo-sasha',
#    'apelido': 'Eduardo Sasha',
#    'apelido_abreviado': 'E. Sasha',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/23/c4219f6ceb958aef5f871e8ecf08b6a5_FORMATO.png',
#    'atleta_id': 70360,
#    'rodada_id': 1,
#    'clube_id': 282,
#    'posicao_id': 5,
#    'status_id': 6,
#    'pontos_num': 0,
#    'preco_num': 7,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Wagner Ferreira dos Santos',
#    'slug': 'wagner',
#    'apelido': 'Wagner',
#    'apelido_abreviado': 'Wagner',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/03/25/4448d1571d9131c2d4f087cf19198f68_FORMATO.png',
#    'atleta_id': 37674,
#    'rodada_id': 1,
#    'clube_id': 286,
#    'posicao_id': 4,
#    'status_id': 5,
#    'pontos_num': 0,
#    'preco_num': 5,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Maurício Nogueira Barbieri',
#    'slug': 'mauricio-barbieri',
#    'apelido': 'Maurício Barbieri',
#    'apelido_abreviado': 'M. Barbieri',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/27/1cc4a56a4aefc5902e503c4834666651_FORMATO.png',
#    'atleta_id': 82792,
#    'rodada_id': 1,
#    'clube_id': 280,
#    'posicao_id': 6,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 7,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Diego Tardelli Martins',
#    'slug': 'diego-tardelli',
#    'apelido': 'Diego Tardelli',
#    'apelido_abreviado': 'D. Tardelli',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/05/02/dc78e14192e3e7061b2fe42448bf4735_FORMATO.png',
#    'atleta_id': 38231,
#    'rodada_id': 1,
#    'clube_id': 282,
#    'posicao_id': 5,
#    'status_id': 6,
#    'pontos_num': 0,
#    'preco_num': 6,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Hélio Júnio Nunes de Castro',
#    'slug': 'helinho',
#    'apelido': 'Helinho',
#    'apelido_abreviado': 'Helinho',
#    'foto': 'https://s.glbimg.com/es/sde/f/2020/11/20/7c0d041c984aed2ad0bddb5980390af3_FORMATO.png',
#    'atleta_id': 102598,
#    'rodada_id': 1,
#    'clube_id': 280,
#    'posicao_id': 5,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 5,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Eduardo Jesús Vargas Rojas',
#    'slug': 'vargas',
#    'apelido': 'Vargas',
#    'apelido_abreviado': 'Vargas',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/23/d29b68b56d66316606b2224987ab6846_FORMATO.png',
#    'atleta_id': 69102,
#    'rodada_id': 1,
#    'clube_id': 282,
#    'posicao_id': 5,
#    'status_id': 6,
#    'pontos_num': 0,
#    'preco_num': 9,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Matías Nicolás Viña Susperreguy',
#    'slug': 'vina',
#    'apelido': 'Viña',
#    'apelido_abreviado': 'Viña',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/30/43d7b4281926b4040d62f2f2494760dc_FORMATO.png',
#    'atleta_id': 98974,
#    'rodada_id': 1,
#    'clube_id': 275,
#    'posicao_id': 2,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 16,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Marcos Vinícius dos Santos Gonçalves',
#    'slug': 'marquinhos-santos',
#    'apelido': 'Marquinhos Santos',
#    'apelido_abreviado': 'M. Santos',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/27/c6a602f75c94ff12016d132e9eb3d8b5_FORMATO.png',
#    'atleta_id': 81031,
#    'rodada_id': 1,
#    'clube_id': 286,
#    'posicao_id': 6,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 3,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Carlos Gilberto do Nascimento Silva',
#    'slug': 'gil',
#    'apelido': 'Gil',
#    'apelido_abreviado': 'Gil',
#    'foto': 'https://s.glbimg.com/es/sde/f/2020/07/21/9d2bb30d4d5c8fa348e34de81829cfa8_FORMATO.png',
#    'atleta_id': 68923,
#    'rodada_id': 1,
#    'clube_id': 264,
#    'posicao_id': 3,
#    'status_id': 6,
#    'pontos_num': 0,
#    'preco_num': 10,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'José Rafael Vivian',
#    'slug': 'ze-rafael',
#    'apelido': 'Zé Rafael ',
#    'apelido_abreviado': 'Z. Rafael',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/30/2a199d6235557f8b6ca773b7fd92b2bd_FORMATO.png',
#    'atleta_id': 82455,
#    'rodada_id': 1,
#    'clube_id': 275,
#    'posicao_id': 4,
#    'status_id': 6,
#    'pontos_num': 0,
#    'preco_num': 8,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Juan Ramón Cazares Sevillano',
#    'slug': 'cazares',
#    'apelido': 'Cazares',
#    'apelido_abreviado': 'Cazares',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/05/06/a1c4029862eedb74993df5c7e9910c16_FORMATO.png',
#    'atleta_id': 81682,
#    'rodada_id': 1,
#    'clube_id': 266,
#    'posicao_id': 4,
#    'status_id': 6,
#    'pontos_num': 0,
#    'preco_num': 9,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Walter Leandro Capeloza Artune',
#    'slug': 'walter',
#    'apelido': 'Walter',
#    'apelido_abreviado': 'Walter',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/03/23/255673408a6fb9bd8a6edcecc52eaa48_FORMATO.png',
#    'atleta_id': 51413,
#    'rodada_id': 1,
#    'clube_id': 1371,
#    'posicao_id': 1,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 5,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Gustavo Raúl Gómez Portillo',
#    'slug': 'gustavo-gomez',
#    'apelido': 'Gustavo Gómez',
#    'apelido_abreviado': 'G. Gómez',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/30/6f48baaa83f44d6a1be5ee2b4f24d2d9_FORMATO.png',
#    'atleta_id': 71684,
#    'rodada_id': 1,
#    'clube_id': 275,
#    'posicao_id': 3,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 17,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Raul Lô Gonçalves',
#    'slug': 'raul',
#    'apelido': 'Raul',
#    'apelido_abreviado': 'Raul',
#    'foto': 'https://s.glbimg.com/es/sde/f/2020/08/28/8c0a624b6d2595beaf51682261e51ccd_FORMATO.png',
#    'atleta_id': 92496,
#    'rodada_id': 1,
#    'clube_id': 280,
#    'posicao_id': 4,
#    'status_id': 5,
#    'pontos_num': 0,
#    'preco_num': 5,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Abel Fernando Moreira Ferreira',
#    'slug': 'abel-ferreira',
#    'apelido': 'Abel Ferreira',
#    'apelido_abreviado': 'A. Ferreira',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/27/574e87d52be9d06fd03fa69fefb60255_FORMATO.png',
#    'atleta_id': 110506,
#    'rodada_id': 1,
#    'clube_id': 275,
#    'posicao_id': 6,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 12,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Vinícius Goes Barbosa de Souza',
#    'slug': 'vina',
#    'apelido': 'Vina',
#    'apelido_abreviado': 'Vina',
#    'foto': 'https://s.glbimg.com/es/sde/f/2020/07/16/66a1394a24c6d86ac402a7ad916cf196_FORMATO.png',
#    'atleta_id': 71162,
#    'rodada_id': 1,
#    'clube_id': 354,
#    'posicao_id': 4,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 18,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Walter Kannemann',
#    'slug': 'kannemann',
#    'apelido': 'Kannemann',
#    'apelido_abreviado': 'Kannemann',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/29/aab069ddcc3f87f133a2d6ea07c4edd4_FORMATO.png',
#    'atleta_id': 87342,
#    'rodada_id': 1,
#    'clube_id': 284,
#    'posicao_id': 3,
#    'status_id': 5,
#    'pontos_num': 0,
#    'preco_num': 11,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Luan Guilherme de Jesus Vieira',
#    'slug': 'luan',
#    'apelido': 'Luan',
#    'apelido_abreviado': 'Luan',
#    'foto': 'https://s.glbimg.com/es/sde/f/2020/07/21/6b23ad91843aeaf82a87d7ac0f322ec2_FORMATO.png',
#    'atleta_id': 86759,
#    'rodada_id': 1,
#    'clube_id': 264,
#    'posicao_id': 4,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 6,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Tiago Retzlaff Nunes',
#    'slug': 'tiago-nunes',
#    'apelido': 'Tiago Nunes',
#    'apelido_abreviado': 'T. Nunes',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/27/70e7cf2c054ba954f48fe011e8e8284e_FORMATO.png',
#    'atleta_id': 98057,
#    'rodada_id': 1,
#    'clube_id': 284,
#    'posicao_id': 6,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 7,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Artur Victor Guimarães',
#    'slug': 'artur',
#    'apelido': 'Artur',
#    'apelido_abreviado': 'Artur',
#    'foto': 'https://s.glbimg.com/es/sde/f/2020/07/28/e1784a425e398f05dd3d8f178a3ddaf6_FORMATO.png',
#    'atleta_id': 95799,
#    'rodada_id': 1,
#    'clube_id': 280,
#    'posicao_id': 5,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 9,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Rodrigo Eduardo Costa Marinho',
#    'slug': 'rodriguinho',
#    'apelido': 'Rodriguinho',
#    'apelido_abreviado': 'Rodriguinho',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/19/d6687890f987db8ea2113e45c58584f1_FORMATO.png',
#    'atleta_id': 61033,
#    'rodada_id': 1,
#    'clube_id': 265,
#    'posicao_id': 4,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 10,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Luan Polli Gomes',
#    'slug': 'luan-polli',
#    'apelido': 'Luan Polli ',
#    'apelido_abreviado': 'L. Polli',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/27/af9cbdc6f5693ba118b6bbe84ffc16d5_FORMATO.png',
#    'atleta_id': 88916,
#    'rodada_id': 1,
#    'clube_id': 292,
#    'posicao_id': 1,
#    'status_id': 6,
#    'pontos_num': 0,
#    'preco_num': 6,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Gustavo Henrique Furtado Scarpa',
#    'slug': 'gustavo-scarpa',
#    'apelido': 'Gustavo Scarpa',
#    'apelido_abreviado': 'G. Scarpa',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/30/e594285e6781941b0f08b58d66d6669e_FORMATO.png',
#    'atleta_id': 87999,
#    'rodada_id': 1,
#    'clube_id': 275,
#    'posicao_id': 4,
#    'status_id': 6,
#    'pontos_num': 0,
#    'preco_num': 8,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Richard de Oliveira da Costa',
#    'slug': 'richard',
#    'apelido': 'Richard',
#    'apelido_abreviado': 'Richard',
#    'foto': 'https://s.glbimg.com/es/sde/f/2020/08/31/b4171a404ece6ec54f9a350c1f02f874_FORMATO.png',
#    'atleta_id': 78851,
#    'rodada_id': 1,
#    'clube_id': 354,
#    'posicao_id': 1,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 6,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Thaciano Mickael da Silva',
#    'slug': 'thaciano',
#    'apelido': 'Thaciano',
#    'apelido_abreviado': 'Thaciano',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/17/5c87b3b06bc58a1fefb780c26b843076_FORMATO.png',
#    'atleta_id': 87470,
#    'rodada_id': 1,
#    'clube_id': 265,
#    'posicao_id': 4,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 6,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Mário Sérgio Santos Costa',
#    'slug': 'marinho',
#    'apelido': 'Marinho',
#    'apelido_abreviado': 'Marinho',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/05/04/ed157c234599d01c370049565c5fa3a8_FORMATO.png',
#    'atleta_id': 68952,
#    'rodada_id': 1,
#    'clube_id': 277,
#    'posicao_id': 5,
#    'status_id': 2,
#    'pontos_num': 0,
#    'preco_num': 23,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Ramiro Moschen Benetti',
#    'slug': 'ramiro',
#    'apelido': 'Ramiro',
#    'apelido_abreviado': 'Ramiro',
#    'foto': 'https://s.glbimg.com/es/sde/f/2020/07/21/e0a5bdd5ef228e8a11c02f81d9776f1f_FORMATO.png',
#    'atleta_id': 78715,
#    'rodada_id': 1,
#    'clube_id': 264,
#    'posicao_id': 4,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 6,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Aldemir dos Santos Ferreira',
#    'slug': 'ferreira',
#    'apelido': 'Ferreira',
#    'apelido_abreviado': 'Ferreira',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/29/c162773146af15b4d212ad3d8e81af03_FORMATO.png',
#    'atleta_id': 101290,
#    'rodada_id': 1,
#    'clube_id': 284,
#    'posicao_id': 5,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 11,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Cleiton Schwengber',
#    'slug': 'cleiton',
#    'apelido': 'Cleiton',
#    'apelido_abreviado': 'Cleiton',
#    'foto': 'https://s.glbimg.com/es/sde/f/2020/08/11/56999db7c665007bbfe8c1e1b0e76f8d_FORMATO.png',
#    'atleta_id': 93882,
#    'rodada_id': 1,
#    'clube_id': 280,
#    'posicao_id': 1,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 4,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Luiz Otávio Anacleto Leandro',
#    'slug': 'luiz-otavio',
#    'apelido': 'Luiz Otávio',
#    'apelido_abreviado': 'L. Otávio',
#    'foto': 'https://s.glbimg.com/es/sde/f/2020/08/31/03f318322bad08093324500b97948211_FORMATO.png',
#    'atleta_id': 72359,
#    'rodada_id': 1,
#    'clube_id': 354,
#    'posicao_id': 3,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 7,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Marcos Felipe de Freitas Monteiro',
#    'slug': 'marcos-felipe',
#    'apelido': 'Marcos Felipe ',
#    'apelido_abreviado': 'M. Felipe',
#    'foto': 'https://s.glbimg.com/es/sde/f/2020/08/11/1e384aacfbb6566d7f8e26a14bdb07ed_FORMATO.png',
#    'atleta_id': 85004,
#    'rodada_id': 1,
#    'clube_id': 266,
#    'posicao_id': 1,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 10,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Francisco Vítor Silva Costa',
#    'slug': 'victor-jacare',
#    'apelido': 'Victor Jacaré',
#    'apelido_abreviado': 'V. Jacaré',
#    'foto': 'https://s.glbimg.com/es/sde/f/2020/08/25/682aea868615c09c3571352b835cc394_FORMATO.png',
#    'atleta_id': 101201,
#    'rodada_id': 1,
#    'clube_id': 354,
#    'posicao_id': 5,
#    'status_id': 5,
#    'pontos_num': 0,
#    'preco_num': 3,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Felipe Jonatan Rocha Andrade',
#    'slug': 'felipe-jonatan',
#    'apelido': 'Felipe Jonatan',
#    'apelido_abreviado': 'F. Jonatan',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/05/04/4798cebd9fdb63bb8aafec616e2b9786_FORMATO.png',
#    'atleta_id': 101708,
#    'rodada_id': 1,
#    'clube_id': 277,
#    'posicao_id': 2,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 11,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Luan Peres Petroni',
#    'slug': 'luan-peres',
#    'apelido': 'Luan Peres ',
#    'apelido_abreviado': 'L. Peres',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/05/04/d665dd0b45438b8e8fd7a50cf9b005db_FORMATO.png',
#    'atleta_id': 84847,
#    'rodada_id': 1,
#    'clube_id': 277,
#    'posicao_id': 3,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 8,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Jony Alexander González Copete',
#    'slug': 'yony-gonzalez',
#    'apelido': 'Yony González',
#    'apelido_abreviado': 'Y. González',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/03/11/1fdc76b6718e0047cc575c51cd3e182c_FORMATO.png',
#    'atleta_id': 97080,
#    'rodada_id': 1,
#    'clube_id': 354,
#    'posicao_id': 5,
#    'status_id': 6,
#    'pontos_num': 0,
#    'preco_num': 5,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Martín Nicolás Benítez',
#    'slug': 'benitez',
#    'apelido': 'Benítez',
#    'apelido_abreviado': 'Benítez',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/07/7dffa59290f8151614a6d7e9a86db08c_FORMATO.png',
#    'atleta_id': 93550,
#    'rodada_id': 1,
#    'clube_id': 276,
#    'posicao_id': 4,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 9,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Severino do Ramo Clementino da Silva',
#    'slug': 'nino-paraiba',
#    'apelido': 'Nino Paraíba',
#    'apelido_abreviado': 'N. Paraíba',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/19/ca9f764ab6737639cb0b1773cb5cbc1c_FORMATO.png',
#    'atleta_id': 68808,
#    'rodada_id': 1,
#    'clube_id': 265,
#    'posicao_id': 2,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 9,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Reinaldo Manoel da Silva',
#    'slug': 'reinaldo',
#    'apelido': 'Reinaldo',
#    'apelido_abreviado': 'Reinaldo',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/05/01/c9612f3f19ae82c35496efdd0780b6fd_FORMATO.png',
#    'atleta_id': 78850,
#    'rodada_id': 1,
#    'clube_id': 276,
#    'posicao_id': 2,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 17,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'John Stiven Mendoza Valencia',
#    'slug': 'mendoza',
#    'apelido': 'Mendoza',
#    'apelido_abreviado': 'Mendoza',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/03/11/adf62456aacb951931d4be8a2e6595ca_FORMATO.png',
#    'atleta_id': 90031,
#    'rodada_id': 1,
#    'clube_id': 354,
#    'posicao_id': 5,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 8,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Luis Manuel Orejuela García',
#    'slug': 'orejuela',
#    'apelido': 'Orejuela',
#    'apelido_abreviado': 'Orejuela',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/05/01/98db4f148382ed26fb0df803e0881f05_FORMATO.png',
#    'atleta_id': 95352,
#    'rodada_id': 1,
#    'clube_id': 276,
#    'posicao_id': 2,
#    'status_id': 6,
#    'pontos_num': 0,
#    'preco_num': 9,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Laércio Soldá',
#    'slug': 'laercio',
#    'apelido': 'Laércio',
#    'apelido_abreviado': 'Laércio',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/01/b1e273caeb30f4ec8f31e217584e31f1_FORMATO.png',
#    'atleta_id': 82564,
#    'rodada_id': 1,
#    'clube_id': 315,
#    'posicao_id': 3,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 5,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Bruno dos Santos Nazário',
#    'slug': 'bruno-nazario',
#    'apelido': 'Bruno Nazário',
#    'apelido_abreviado': 'B. Nazário',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/20/bfb1efa9e0920fe903d137aec965d3c6_FORMATO.png',
#    'atleta_id': 81776,
#    'rodada_id': 1,
#    'clube_id': 327,
#    'posicao_id': 4,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 6,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Frederico Chaves Guedes',
#    'slug': 'fred',
#    'apelido': 'Fred',
#    'apelido_abreviado': 'Fred',
#    'foto': 'https://s.glbimg.com/es/sde/f/2020/08/11/1546fc5edcfb41d2e8f79f6eca1f6899_FORMATO.png',
#    'atleta_id': 38162,
#    'rodada_id': 1,
#    'clube_id': 266,
#    'posicao_id': 5,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 12,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Felipe Alves Raymundo',
#    'slug': 'felipe-alves',
#    'apelido': 'Felipe Alves',
#    'apelido_abreviado': 'F. Alves',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/05/05/7f2817bd88a2722833e451d34ef533fa_FORMATO.png',
#    'atleta_id': 72372,
#    'rodada_id': 1,
#    'clube_id': 356,
#    'posicao_id': 1,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 9,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Thiago Neves Augusto',
#    'slug': 'thiago-neves',
#    'apelido': 'Thiago Neves',
#    'apelido_abreviado': 'T. Neves',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/27/5774f300d0560c7ea0d91ad7c34a9c26_FORMATO.png',
#    'atleta_id': 38277,
#    'rodada_id': 1,
#    'clube_id': 292,
#    'posicao_id': 4,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 10,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Pedro Henrique Perotti',
#    'slug': 'perotti',
#    'apelido': 'Perotti',
#    'apelido_abreviado': 'Perotti',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/03/23/17acb053b61edf1d764249f524bbc93e_FORMATO.png',
#    'atleta_id': 94286,
#    'rodada_id': 1,
#    'clube_id': 315,
#    'posicao_id': 5,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 6,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Matheus Vieira Campos Peixoto',
#    'slug': 'matheus-peixoto',
#    'apelido': 'Matheus Peixoto',
#    'apelido_abreviado': 'M. Peixoto',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/03/25/908c07b7f8cb73a7773abe1cc2b2dcdc_FORMATO.png',
#    'atleta_id': 87098,
#    'rodada_id': 1,
#    'clube_id': 286,
#    'posicao_id': 5,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 4,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Mozart Santos Batista Júnior',
#    'slug': 'mozart',
#    'apelido': 'Mozart',
#    'apelido_abreviado': 'Mozart',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/28/1b285c358820875b2cc9642a608ac627_FORMATO.png',
#    'atleta_id': 109627,
#    'rodada_id': 1,
#    'clube_id': 315,
#    'posicao_id': 6,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 2,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Hernán Jorge Crespo',
#    'slug': 'hernan-crespo',
#    'apelido': 'Hernán Crespo',
#    'apelido_abreviado': 'H. Crespo',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/27/39f37d3c66285f42403fbbf4313aa5b1_FORMATO.png',
#    'atleta_id': 103912,
#    'rodada_id': 1,
#    'clube_id': 276,
#    'posicao_id': 6,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 10,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Raphael Cavalcante Veiga',
#    'slug': 'raphael-veiga',
#    'apelido': 'Raphael Veiga',
#    'apelido_abreviado': 'R. Veiga',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/30/c4c1b91cbd4ff74465329b542ccd0c6d_FORMATO.png',
#    'atleta_id': 94509,
#    'rodada_id': 1,
#    'clube_id': 275,
#    'posicao_id': 4,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 15,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Paulo Roberto Valoura Júnior',
#    'slug': 'juninho-valoura',
#    'apelido': 'Juninho Valoura',
#    'apelido_abreviado': 'J. Valoura',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/13/cdbe82d3b9128d3dcd562bc848db62aa_FORMATO.png',
#    'atleta_id': 71937,
#    'rodada_id': 1,
#    'clube_id': 327,
#    'posicao_id': 4,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 7,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Diego Souza de Andrade',
#    'slug': 'diego-souza',
#    'apelido': 'Diego Souza',
#    'apelido_abreviado': 'D. Souza',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/29/a861c36a70f6c8c2ca8e65c0d0347c59_FORMATO.png',
#    'atleta_id': 68911,
#    'rodada_id': 1,
#    'clube_id': 284,
#    'posicao_id': 5,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 19,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Luciano da Rocha Neves',
#    'slug': 'luciano',
#    'apelido': 'Luciano',
#    'apelido_abreviado': 'Luciano',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/05/01/960732cf5147a9053097293f6972b1d6_FORMATO.png',
#    'atleta_id': 80287,
#    'rodada_id': 1,
#    'clube_id': 276,
#    'posicao_id': 5,
#    'status_id': 5,
#    'pontos_num': 0,
#    'preco_num': 18,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Wellington Pereira do Nascimento',
#    'slug': 'wellington-paulista',
#    'apelido': 'Wellington Paulista',
#    'apelido_abreviado': 'W. Paulista',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/05/05/61649405651455f860b80916f5c30bf0_FORMATO.png',
#    'atleta_id': 38279,
#    'rodada_id': 1,
#    'clube_id': 356,
#    'posicao_id': 5,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 8,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'David Correa da Fonseca',
#    'slug': 'david',
#    'apelido': 'David',
#    'apelido_abreviado': 'David',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/05/05/7f9ce8d7ba7bcdaa8211fa7a9a8fef0a_FORMATO.png',
#    'atleta_id': 90309,
#    'rodada_id': 1,
#    'clube_id': 356,
#    'posicao_id': 5,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 7,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Guilherme de Jesus da Silva',
#    'slug': 'tinga',
#    'apelido': 'Tinga',
#    'apelido_abreviado': 'Tinga',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/05/05/55684c2f5239196e41f100ff8aec49fc_FORMATO.png',
#    'atleta_id': 82628,
#    'rodada_id': 1,
#    'clube_id': 356,
#    'posicao_id': 2,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 7,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Umberto Lourenço Louzer Filho',
#    'slug': 'umberto-louzer',
#    'apelido': 'Umberto Louzer',
#    'apelido_abreviado': 'U. Louzer',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/15/6b25bcef84ca2ca67c4b19b4e5356ca3_FORMATO.png',
#    'atleta_id': 101077,
#    'rodada_id': 1,
#    'clube_id': 292,
#    'posicao_id': 6,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 2,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Felipe Azevedo dos Santos',
#    'slug': 'felipe-azevedo',
#    'apelido': 'Felipe Azevedo',
#    'apelido_abreviado': 'F. Azevedo',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/03/29/e2f0f2bc1d055efb31039770126ec6fd_FORMATO.png',
#    'atleta_id': 60825,
# ...
#    'rodada_id': 1,
#    'clube_id': 275,
#    'posicao_id': 3,
#    'status_id': 6,
#    'pontos_num': 0,
#    'preco_num': 1,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'José Cássio Meneses da Costa ',
#    'slug': 'cassio',
#    'apelido': 'Cássio',
#    'apelido_abreviado': 'Cássio',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/30/654d03002d98b0dabf6606ac306a2158_FORMATO.png',
#    'atleta_id': 113250,
#    'rodada_id': 1,
#    'clube_id': 327,
#    'posicao_id': 1,
#    'status_id': 6,
#    'pontos_num': 0,
#    'preco_num': 1,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Felipe Siedekum',
#    'slug': 'felipe-siedekum',
#    'apelido': 'Felipe Siedekum',
#    'apelido_abreviado': 'F. Siedekum',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/30/5fd5366dbf98155cf267cb466b762b19_FORMATO.png',
#    'atleta_id': 113251,
#    'rodada_id': 1,
#    'clube_id': 327,
#    'posicao_id': 3,
#    'status_id': 6,
#    'pontos_num': 0,
#    'preco_num': 1,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Jefté Vital da Silva Dias\t',
#    'slug': 'jefte',
#    'apelido': 'Jefté',
#    'apelido_abreviado': 'Jefté',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/26/90471195ecec6b861908598eb5a8dcf5_FORMATO.png',
#    'atleta_id': 111832,
#    'rodada_id': 1,
#    'clube_id': 266,
#    'posicao_id': 2,
#    'status_id': 6,
#    'pontos_num': 0,
#    'preco_num': 2,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Luis Gustavo da Silva Machado Duarte',
#    'slug': 'luis-mandaca',
#    'apelido': 'Luis Mandaca',
#    'apelido_abreviado': 'L. Mandaca',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/02/22/9cee7f3e748fe234ee2ae2a206ca68c9_FORMATO.png',
#    'atleta_id': 111407,
#    'rodada_id': 1,
#    'clube_id': 264,
#    'posicao_id': 4,
#    'status_id': 6,
#    'pontos_num': 0,
#    'preco_num': 2,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Pedro Felipe De Faria Rangel',
#    'slug': 'pedro-rangel',
#    'apelido': 'Pedro Rangel',
#    'apelido_abreviado': 'P. Rangel',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/03/15/c6a50dd60d02aef2d777eae59ef28c14_FORMATO.png',
#    'atleta_id': 110708,
#    'rodada_id': 1,
#    'clube_id': 266,
#    'posicao_id': 1,
#    'status_id': 6,
#    'pontos_num': 0,
#    'preco_num': 1,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Leonardo Rodrigues dos Santos',
#    'slug': 'leo-santos',
#    'apelido': 'Léo Santos',
#    'apelido_abreviado': 'L. Santos',
#    'foto': 'https://s.glbimg.com/es/sde/f/2020/07/21/c10deb3a4469411c9e7ee2bee05fbeea_FORMATO.png',
#    'atleta_id': 95820,
#    'rodada_id': 1,
#    'clube_id': 264,
#    'posicao_id': 3,
#    'status_id': 6,
#    'pontos_num': 0,
#    'preco_num': 2,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Fernando José Pacheco Rivas',
#    'slug': 'fernando-pacheco',
#    'apelido': 'Fernando Pacheco',
#    'apelido_abreviado': 'F. Pacheco',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/05/10/b074df9a6a044fea160c30b182390ec6_FORMATO.png',
#    'atleta_id': 98740,
#    'rodada_id': 1,
#    'clube_id': 286,
#    'posicao_id': 5,
#    'status_id': 6,
#    'pontos_num': 0,
#    'preco_num': 4,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Fernando Diniz Silva',
#    'slug': 'fernando-diniz',
#    'apelido': 'Fernando Diniz',
#    'apelido_abreviado': 'F. Diniz',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/05/09/62a59a2e7ec6602b8811cb920c3c3dba_FORMATO.png',
#    'atleta_id': 72391,
#    'rodada_id': 1,
#    'clube_id': 277,
#    'posicao_id': 6,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 5,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Vitor Hugo Paes do Santo',
#    'slug': 'vitor-hugo',
#    'apelido': 'Vitor Hugo',
#    'apelido_abreviado': 'V. Hugo',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/05/13/c643f7dc0402bf55669d7b265dd569bd_FORMATO.png',
#    'atleta_id': 111697,
#    'rodada_id': 1,
#    'clube_id': 1371,
#    'posicao_id': 3,
#    'status_id': 6,
#    'pontos_num': 0,
#    'preco_num': 1,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Carlos Andrés Sánchez Arcosa',
#    'slug': 'carlos-sanchez',
#    'apelido': 'Carlos Sánchez',
#    'apelido_abreviado': 'C. Sánchez',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/05/04/0114554943a088276966824a3ae8496b_FORMATO.png',
#    'atleta_id': 81677,
#    'rodada_id': 1,
#    'clube_id': 277,
#    'posicao_id': 4,
#    'status_id': 6,
#    'pontos_num': 0,
#    'preco_num': 10,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Jaderson Flores dos Reis',
#    'slug': 'jaderson',
#    'apelido': 'Jaderson',
#    'apelido_abreviado': 'Jaderson',
#    'foto': 'https://s.glbimg.com/es/sde/f/2019/03/30/832c92b15aa34fdde7be9738ca86c863_FORMATO.png',
#    'atleta_id': 98224,
#    'rodada_id': 1,
#    'clube_id': 293,
#    'posicao_id': 4,
#    'status_id': 6,
#    'pontos_num': 0,
#    'preco_num': 2,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Luiz Felipe do Nascimento dos Santos',
#    'slug': 'luiz-felipe',
#    'apelido': 'Luiz Felipe',
#    'apelido_abreviado': 'L. Felipe',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/05/04/366dc640a3169c956de4dd3e43472be2_FORMATO.png',
#    'atleta_id': 79035,
#    'rodada_id': 1,
#    'clube_id': 277,
#    'posicao_id': 3,
#    'status_id': 6,
#    'pontos_num': 0,
#    'preco_num': 4,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Thiago dos Santos',
#    'slug': 'thiago-santos',
#    'apelido': 'Thiago Santos',
#    'apelido_abreviado': 'T. Santos',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/29/78a3913eadf71b266b9cde467311d370_FORMATO.png',
#    'atleta_id': 78855,
#    'rodada_id': 1,
#    'clube_id': 284,
#    'posicao_id': 4,
#    'status_id': 2,
#    'pontos_num': 0,
#    'preco_num': 5,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Fernando Rodrigues Caixeta Barbosa',
#    'slug': 'fernando',
#    'apelido': 'Fernando',
#    'apelido_abreviado': 'Fernando',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/03/23/a9173ea528c29585fe865aef7b74c30e_FORMATO.png',
#    'atleta_id': 97543,
#    'rodada_id': 1,
#    'clube_id': 1371,
#    'posicao_id': 1,
#    'status_id': 6,
#    'pontos_num': 0,
#    'preco_num': 1,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Wescley Gomes dos Santos',
#    'slug': 'wescley',
#    'apelido': 'Wescley',
#    'apelido_abreviado': 'Wescley',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/04/20/c608ca2323650a82af7be359fe111dec_FORMATO.png',
#    'atleta_id': 70925,
#    'rodada_id': 1,
#    'clube_id': 286,
#    'posicao_id': 4,
#    'status_id': 2,
#    'pontos_num': 0,
#    'preco_num': 3,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'Lucas Ramon Batista da Silva',
#    'slug': 'lucas-ramon',
#    'apelido': 'Lucas Ramon ',
#    'apelido_abreviado': 'L. Ramon',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/03/23/ff3496e240335b790ebd871c5a7f4819_FORMATO.png',
#    'atleta_id': 82775,
#    'rodada_id': 1,
#    'clube_id': 1371,
#    'posicao_id': 2,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 3,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}},
#   {'nome': 'João Paulo Silva Martins',
#    'slug': 'joao-paulo',
#    'apelido': 'João Paulo',
#    'apelido_abreviado': 'J. Paulo',
#    'foto': 'https://s.glbimg.com/es/sde/f/2021/05/04/e9d3dc6f19ff09461dc2f3f5d0a5bd61_FORMATO.png',
#    'atleta_id': 85425,
#    'rodada_id': 1,
#    'clube_id': 277,
#    'posicao_id': 1,
#    'status_id': 7,
#    'pontos_num': 0,
#    'preco_num': 8,
#    'variacao_num': 0,
#    'media_num': 0,
#    'jogos_num': 0,
#    'scout': {}}],
#  'clubes': {'1371': {'id': 1371,
#    'nome': 'Cuiabá',
#    'abreviacao': 'CUI',
#    'escudos': {'60x60': 'https://s.glbimg.com/es/sde/f/organizacoes/2014/04/16/cuiaba65.png',
#     '45x45': 'https://s.glbimg.com/es/sde/f/organizacoes/2014/04/16/cuiaba45.png',
#     '30x30': 'https://s.glbimg.com/es/sde/f/organizacoes/2014/04/16/cuiaba30_.png'},
#    'nome_fantasia': 'Cuiabá'},
#   '262': {'id': 262,
#    'nome': 'Flamengo',
#    'abreviacao': 'FLA',
#    'escudos': {'60x60': 'https://s.glbimg.com/es/sde/f/organizacoes/2018/04/09/Flamengo-65.png',
#     '45x45': 'https://s.glbimg.com/es/sde/f/organizacoes/2018/04/09/Flamengo-45.png',
#     '30x30': 'https://s.glbimg.com/es/sde/f/organizacoes/2018/04/09/Flamengo-30.png'},
#    'nome_fantasia': 'Flamengo'},
#   '264': {'id': 264,
#    'nome': 'Corinthians',
#    'abreviacao': 'COR',
#    'escudos': {'60x60': 'https://s.glbimg.com/es/sde/f/organizacoes/2019/09/30/Corinthians_65.png',
#     '45x45': 'https://s.glbimg.com/es/sde/f/organizacoes/2019/09/30/Corinthians_45.png',
#     '30x30': 'https://s.glbimg.com/es/sde/f/organizacoes/2019/09/30/Corinthians_30.png'},
#    'nome_fantasia': 'Corinthians'},
#   '265': {'id': 265,
#    'nome': 'Bahia',
#    'abreviacao': 'BAH',
#    'escudos': {'60x60': 'https://s.glbimg.com/es/sde/f/organizacoes/2014/04/14/bahia_60x60.png',
#     '45x45': 'https://s.glbimg.com/es/sde/f/organizacoes/2014/04/14/bahia_45x45.png',
#     '30x30': 'https://s.glbimg.com/es/sde/f/organizacoes/2014/04/14/bahia_30x30.png'},
#    'nome_fantasia': 'Bahia'},
#   '266': {'id': 266,
#    'nome': 'Fluminense',
#    'abreviacao': 'FLU',
#    'escudos': {'60x60': 'https://s.glbimg.com/es/sde/f/organizacoes/2014/04/14/fluminense_60x60.png',
#     '45x45': 'https://s.glbimg.com/es/sde/f/organizacoes/2014/04/14/fluminense_45x45.png',
#     '30x30': 'https://s.glbimg.com/es/sde/f/organizacoes/2015/01/12/Fluminense-escudo.png'},
#    'nome_fantasia': 'Fluminense'},
#   '275': {'id': 275,
#    'nome': 'Palmeiras',
#    'abreviacao': 'PAL',
#    'escudos': {'60x60': 'https://s.glbimg.com/es/sde/f/organizacoes/2014/04/14/palmeiras_60x60.png',
#     '45x45': 'https://s.glbimg.com/es/sde/f/organizacoes/2014/04/14/palmeiras_45x45.png',
#     '30x30': 'https://s.glbimg.com/es/sde/f/organizacoes/2014/04/14/palmeiras_30x30.png'},
#    'nome_fantasia': 'Palmeiras'},
#   '276': {'id': 276,
#    'nome': 'São Paulo',
#    'abreviacao': 'SAO',
#    'escudos': {'60x60': 'https://s.glbimg.com/es/sde/f/organizacoes/2014/04/14/sao_paulo_60x60.png',
#     '45x45': 'https://s.glbimg.com/es/sde/f/organizacoes/2014/04/14/sao_paulo_45x45.png',
#     '30x30': 'https://s.glbimg.com/es/sde/f/organizacoes/2014/04/14/sao_paulo_30x30.png'},
#    'nome_fantasia': 'São Paulo'},
#   '277': {'id': 277,
#    'nome': 'Santos',
#    'abreviacao': 'SAN',
#    'escudos': {'60x60': 'https://s.glbimg.com/es/sde/f/organizacoes/2014/04/14/santos_60x60.png',
#     '45x45': 'https://s.glbimg.com/es/sde/f/organizacoes/2014/04/14/santos_45x45.png',
#     '30x30': 'https://s.glbimg.com/es/sde/f/organizacoes/2014/04/14/santos_30x30.png'},
#    'nome_fantasia': 'Santos'},
#   '280': {'id': 280,
#    'nome': 'Bragantino',
#    'abreviacao': 'BGT',
#    'escudos': {'60x60': 'https://s.glbimg.com/es/sde/f/organizacoes/2020/01/01/65.png',
#     '45x45': 'https://s.glbimg.com/es/sde/f/organizacoes/2020/01/01/45.png',
#     '30x30': 'https://s.glbimg.com/es/sde/f/organizacoes/2020/01/01/30.png'},
#    'nome_fantasia': 'Bragantino'},
#   '282': {'id': 282,
#    'nome': 'Atlético-MG',
#    'abreviacao': 'CAM',
#    'escudos': {'60x60': 'https://s.glbimg.com/es/sde/f/organizacoes/2017/11/23/Atletico-Mineiro-escudo65px.png',
#     '45x45': 'https://s.glbimg.com/es/sde/f/organizacoes/2017/11/23/Atletico-Mineiro-escudo45px.png',
#     '30x30': 'https://s.glbimg.com/es/sde/f/organizacoes/2017/11/23/Atletico-Mineiro-escudo30px.png'},
#    'nome_fantasia': 'Atlético-MG'},
#   '284': {'id': 284,
#    'nome': 'Grêmio',
#    'abreviacao': 'GRE',
#    'escudos': {'60x60': 'https://s.glbimg.com/es/sde/f/organizacoes/2014/04/14/gremio_60x60.png',
#     '45x45': 'https://s.glbimg.com/es/sde/f/organizacoes/2014/04/14/gremio_45x45.png',
#     '30x30': 'https://s.glbimg.com/es/sde/f/organizacoes/2014/04/14/gremio_30x30.png'},
#    'nome_fantasia': 'Grêmio'},
#   '285': {'id': 285,
#    'nome': 'Internacional',
#    'abreviacao': 'INT',
#    'escudos': {'60x60': 'https://s.glbimg.com/es/sde/f/organizacoes/2016/05/03/inter65.png',
#     '45x45': 'https://s.glbimg.com/es/sde/f/organizacoes/2016/05/03/inter45.png',
#     '30x30': 'https://s.glbimg.com/es/sde/f/organizacoes/2016/05/03/inter30.png'},
#    'nome_fantasia': 'Internacional'},
#   '286': {'id': 286,
#    'nome': 'Juventude',
#    'abreviacao': 'JUV',
#    'escudos': {'60x60': 'https://s.glbimg.com/es/sde/f/organizacoes/2016/05/08/juventude65.png',
#     '45x45': 'https://s.glbimg.com/es/sde/f/organizacoes/2016/05/08/juventude45.png',
#     '30x30': 'https://s.glbimg.com/es/sde/f/organizacoes/2016/05/08/juventude30.png'},
#    'nome_fantasia': 'Juventude'},
#   '292': {'id': 292,
#    'nome': 'Sport',
#    'abreviacao': 'SPT',
#    'escudos': {'60x60': 'https://s.glbimg.com/es/sde/f/organizacoes/2015/07/21/sport65.png',
#     '45x45': 'https://s.glbimg.com/es/sde/f/organizacoes/2015/07/21/sport45.png',
#     '30x30': 'https://s.glbimg.com/es/sde/f/organizacoes/2015/07/21/sport30.png'},
#    'nome_fantasia': 'Sport'},
#   '293': {'id': 293,
#    'nome': 'Athlético-PR',
#    'abreviacao': 'CAP',
#    'escudos': {'60x60': 'https://s.glbimg.com/es/sde/f/organizacoes/2019/09/09/Athletico-PR-65x65.png',
#     '45x45': 'https://s.glbimg.com/es/sde/f/organizacoes/2019/09/09/Athletico-PR-45x45.png',
#     '30x30': 'https://s.glbimg.com/es/sde/f/organizacoes/2019/09/09/Athletico-PR-30x30.png'},
#    'nome_fantasia': 'Athlético-PR'},
#   '315': {'id': 315,
#    'nome': 'Chapecoense',
#    'abreviacao': 'CHA',
#    'escudos': {'60x60': 'https://s.glbimg.com/es/sde/f/organizacoes/2015/08/03/Escudo-Chape-165.png',
#     '45x45': 'https://s.glbimg.com/es/sde/f/organizacoes/2015/08/03/Escudo-Chape-145.png',
#     '30x30': 'https://s.glbimg.com/es/sde/f/organizacoes/2015/08/03/Escudo-Chape-130.png'},
#    'nome_fantasia': 'Chapecoense'},
#   '327': {'id': 327,
#    'nome': 'América-MG',
#    'abreviacao': 'AME',
#    'escudos': {'60x60': 'https://s.glbimg.com/es/sde/f/organizacoes/2019/02/28/escudo65_1.png',
#     '45x45': 'https://s.glbimg.com/es/sde/f/organizacoes/2019/02/28/escudo45_1.png',
#     '30x30': 'https://s.glbimg.com/es/sde/f/organizacoes/2019/02/28/escudo30.png'},
#    'nome_fantasia': 'América-MG'},
#   '354': {'id': 354,
#    'nome': 'Ceará',
#    'abreviacao': 'CEA',
#    'escudos': {'60x60': 'https://s.glbimg.com/es/sde/f/organizacoes/2019/10/10/ceara-65x65.png',
#     '45x45': 'https://s.glbimg.com/es/sde/f/organizacoes/2019/10/10/ceara-45x45.png',
#     '30x30': 'https://s.glbimg.com/es/sde/f/organizacoes/2019/10/10/ceara-30x30.png'},
#    'nome_fantasia': 'Ceará'},
#   '356': {'id': 356,
#    'nome': 'Fortaleza',
#    'abreviacao': 'FOR',
#    'escudos': {'60x60': 'https://s.glbimg.com/es/sde/f/organizacoes/2018/06/10/fortaleza-ec-65px.png',
#     '45x45': 'https://s.glbimg.com/es/sde/f/organizacoes/2018/06/10/fortaleza-ec-45px.png',
#     '30x30': 'https://s.glbimg.com/es/sde/f/organizacoes/2018/06/10/fortaleza-ec-30px.png'},
#    'nome_fantasia': 'Fortaleza'},
#   '373': {'id': 373,
#    'nome': 'Atlético-GO',
#    'abreviacao': 'ACG',
#    'escudos': {'60x60': 'https://s.glbimg.com/es/sde/f/organizacoes/2020/07/02/atletico-go-2020-65.png',
#     '45x45': 'https://s.glbimg.com/es/sde/f/organizacoes/2020/07/02/atletico-go-2020-45.png',
#     '30x30': 'https://s.glbimg.com/es/sde/f/organizacoes/2020/07/02/atletico-go-2020-30.png'},
#    'nome_fantasia': 'Atlético-GO'}},
#  'posicoes': {'1': {'id': 1, 'nome': 'Goleiro', 'abreviacao': 'gol'},
#   '2': {'id': 2, 'nome': 'Lateral', 'abreviacao': 'lat'},
#   '3': {'id': 3, 'nome': 'Zagueiro', 'abreviacao': 'zag'},
#   '4': {'id': 4, 'nome': 'Meia', 'abreviacao': 'mei'},
#   '5': {'id': 5, 'nome': 'Atacante', 'abreviacao': 'ata'},
#   '6': {'id': 6, 'nome': 'Técnico', 'abreviacao': 'tec'}},
#  'status': {'2': {'id': 2, 'nome': 'Dúvida'},
#   '3': {'id': 3, 'nome': 'Suspenso'},
#   '5': {'id': 5, 'nome': 'Contundido'},
#   '6': {'id': 6, 'nome': 'Nulo'},
#   '7': {'id': 7, 'nome': 'Provável'}}}
