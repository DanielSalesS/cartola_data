# %% [markdown]
# # Obter dados de uma rodada antiga.

# %%
import json
import path_config
from cartola.api import ApiClient
from cartola.cartola_settings import scout_keys, clubs, club_ids, dynamic_api
from cartola.processdata import Players

# %%
def read_json(path):
    dados = {}
    try:
        with open(path, 'r', encoding="utf-8") as json_file:
            dados = json.load(json_file)
    except IOError:
        print("I/O error")

    return dados

# %% [markdown]
# ## Selecionando uma rodada antiga

# %%
rodada = 26

path = fr'json_files/rodada{rodada}/atletas_mercado_{rodada}.json'

dir_path = fr'csv_files/rodada{rodada}'

json_data = read_json(path)
json_data
# Out:
# {'atletas': [{'nome': 'Rodrigo Caio Coquette Russo',
#    'slug': 'rodrigo-caio',
#    'apelido': 'Rodrigo Caio',
#    'foto': 'https://s.glbimg.com/es/sde/f/2020/07/21/235f42a8e045a0d3e49b97de151784b9_FORMATO.png',
#    'atleta_id': 73800,
#    'rodada_id': 25,
#    'clube_id': 262,
#    'posicao_id': 3,
#    'status_id': 7,
#    'pontos_num': 1.3,
#    'preco_num': 8.08,
#    'variacao_num': -0.48,
#    'media_num': 2.77,
#    'jogos_num': 11,
#    'scout': {'CA': 1,
#     'DS': 19,
#     'FC': 12,
#     'FD': 1,
#     'FF': 3,
#     'FS': 6,
#     'PI': 21,
#     'SG': 3}},
#   {'nome': 'Fagner Conserva Lemos',
#    'slug': 'fagner',
#    'apelido': 'Fagner',
#    'foto': 'https://s.glbimg.com/es/sde/f/2020/07/21/86994a3b5f98e1f43ef23a09d56aa65c_FORMATO.png',
#    'atleta_id': 42500,
#    'rodada_id': 25,
#    'clube_id': 264,
#    'posicao_id': 2,
#    'status_id': 7,
#    'pontos_num': 7.7,
#    'preco_num': 11.82,
#    'variacao_num': -0.69,
#    'media_num': 3.74,
# ...

# %% [markdown]
# ## Dados desejados

# %%
#Todos os dados disponiveis 
all_data = [
    'clube_id',
    'nome',
    'slug',
    'apelido',
    'atleta_id',
    'rodada_id',
    'posicao_id',
    'status_id',
    'pontos_num',
    'preco_num',
    'variacao_num',
    'media_num',
    'jogos_num',
    'scout',
]

#Dados desejados.
target_data = [
    'clube_id',
    'nome',
    'slug',
    'apelido',
    'posicao_id',
    'status_id',
    'pontos_num',
    'preco_num',
    'variacao_num',
    'media_num',
    'jogos_num',
    'scout',
]

# %%
1
# Out:
# 1
